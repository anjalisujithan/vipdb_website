# %%
import pandas as pd

df = pd.read_csv("/Users/asujithan/Projects/BrennerResearch/vipdb_orignal.csv")
df.to_json("vipdb.json", orient="records")  # list of row objects
print("Wrote vipdb.json with", len(df), "rows")
# Out:
# Wrote vipdb.json with 407 rows
